# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">The Price is Right - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Autonomous agent framework that finds online deals, collaborating with a proprietary fine-tuned LLM deployed on Modal, and a RAG pipeline with a frontier model and Chroma.</div>')
        

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Updated to change from height to max_height due to change in Gradio v5
# With much thanks to student Ed B. for raising this

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)
# Out:
# [2026-06-15 11:18:01 +0200] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] Use pytorch device_name: cpu
# [2026-06-15 11:18:02 +0200] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-06-15 11:18:05 +0200] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-06-15 11:18:05 +0200] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-06-15 11:18:06 +0200] [Agents] [INFO] Neural Network is using cpu
# [2026-06-15 11:18:06 +0200] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-06-15 11:18:06 +0200] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-06-15 11:18:06 +0200] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-06-15 11:18:06 +0200] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-06-15 11:18:06 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-06-15 11:18:06 +0200] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Time for the code
#
# And now we'll move to the price_is_right.py code

# %%
# Reset memory back to 2 deals discovered in the past

from deal_agent_framework import DealAgentFramework
DealAgentFramework.reset_memory()

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %% [markdown]
# # Running the final product
#
# ## Just hit shift + enter in the next cell, and let the deals flow in!!

# %%
# !uv run price_is_right.py
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] Use pytorch device_name: cpu
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] Use pytorch device_name: cpu
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-06-15 12:04:29 +0200] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-06-15 12:04:32 +0200] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-06-15 12:04:32 +0200] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-06-15 12:04:32 +0200] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-06-15 12:04:32 +0200] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-06-15 12:04:33 +0200] [Agents] [INFO] Neural Network is using cpu
# [2026-06-15 12:04:33 +0200] [Agents] [INFO] Neural Network is using cpu
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] Kicking off Planning Agent
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] Kicking off Planning Agent
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-06-15 12:04:34 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-06-15 12:05:35 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent received 30 deals not already scraped
# [2026-06-15 12:05:35 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent received 30 deals not already scraped
# [2026-06-15 12:05:35 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-06-15 12:05:35 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-06-15 12:05:47 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-06-15 12:05:47 +0200] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-06-15 12:05:47 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-15 12:05:47 +0200] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-15 12:05:47 +0200] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-06-15 12:05:47 +0200] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:05:47 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-06-15 12:05:47 +0200] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-06-15 12:05:47 +0200] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# Exception in thread Thread-6 (worker):
# Traceback (most recent call last):
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_transports/default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_transports/default.py", line 250, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py", line 256, in handle_request
#     raise exc from None
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py", line 236, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py", line 101, in handle_request
#     raise exc
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py", line 78, in handle_request
#     stream = self._connect(request)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py", line 124, in _connect
#     stream = self._network_backend.connect_tcp(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py", line 207, in connect_tcp
#     with map_exceptions(exc_map):
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/.local/share/uv/python/cpython-3.12.12-linux-aarch64-gnu/lib/python3.12/contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py", line 190, in _make_common_sync_call
#     response = sync_httpx_client.post(
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py", line 900, in post
#     raise e
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py", line 879, in post
#     response = self.client.send(req, stream=stream)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py", line 1014, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_transports/default.py", line 249, in handle_request
#     with map_httpcore_exceptions():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/.local/share/uv/python/cpython-3.12.12-linux-aarch64-gnu/lib/python3.12/contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_transports/default.py", line 118, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/main.py", line 3369, in completion
#     response = base_llm_http_handler.completion(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py", line 493, in completion
#     response = self._make_common_sync_call(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py", line 217, in _make_common_sync_call
#     raise self._handle_error(e=e, provider_config=provider_config)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py", line 3517, in _handle_error
#     raise provider_config.get_error_class(
# litellm.llms.ollama.common_utils.OllamaError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/leslawn/.local/share/uv/python/cpython-3.12.12-linux-aarch64-gnu/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/leslawn/.local/share/uv/python/cpython-3.12.12-linux-aarch64-gnu/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/leslawn/projects_dev/llm_engineering/week8/price_is_right.py", line 137, in worker
#     result = do_run()
#              ^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/week8/price_is_right.py", line 127, in do_run
#     new_opportunities = self.get_agent_framework().run()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/week8/deal_agent_framework.py", line 95, in run
#     result = self.planner.plan(memory=self.memory)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/week8/agents/planning_agent.py", line 49, in plan
#     opportunities = [self.run(deal) for deal in selection.deals[:5]]
#                      ^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/week8/agents/planning_agent.py", line 32, in run
#     estimate = self.ensemble.price(deal.product_description)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/week8/agents/ensemble_agent.py", line 33, in price
#     rewrite = self.preprocessor.preprocess(description)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/week8/agents/preprocessor.py", line 39, in preprocess
#     response = completion(
#                ^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py", line 1376, in wrapper
#     raise e
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py", line 1245, in wrapper
#     result = original_function(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/main.py", line 3767, in completion
#     raise exception_type(
#           ^^^^^^^^^^^^^^^
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py", line 2274, in exception_type
#     raise e
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py", line 2243, in exception_type
#     raise APIConnectionError(
# litellm.exceptions.APIConnectionError: litellm.APIConnectionError: OllamaException - [Errno 111] Connection refused
# Keyboard interruption in main thread... closing server.
# ^C
# Traceback (most recent call last):
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2958, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/leslawn/projects_dev/llm_engineering/week8/price_is_right.py", line 196, in <module>
#     App().run()
#   File "/home/leslawn/projects_dev/llm_engineering/week8/price_is_right.py", line 192, in run
#     ui.launch(share=False, inbrowser=True)
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2865, in launch
#     self.block_thread()
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2962, in block_thread
#     self.server.close()
#   File "/home/leslawn/projects_dev/llm_engineering/.venv/lib/python3.12/site-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/home/leslawn/.local/share/uv/python/cpython-3.12.12-linux-aarch64-gnu/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/home/leslawn/.local/share/uv/python/cpython-3.12.12-linux-aarch64-gnu/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#a22;">But wait!! There's more..</h2>
#             <span style="color:#a22;">If you're not fed up of product prices yet 😂 I've built this out some more!<br/>
#             If you look in my repo <a href="https://github.com/ed-donner/tech2ai">tech2ai</a>, in segment4 is a version that uses OpenAI Agents SDK for the AutonomousPlanningAgent, and makes use of MCP servers.  If you're intrigued by Agents and MCP, and would like to learn more, then I also have a companion course on this. This, along with my 2 other companion courses, are laid out in my <a href="https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/">complete AI curriculum</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">CONGRATULATIONS AND THANK YOU!!!</h2>
#             <span style="color:#090;">
#                 It's so fabulous that you've made it to the very end! My heartiest congratulations. Please stay in touch! I'm <a href="https://www.linkedin.com/in/eddonner/">here on LinkedIn</a> if we're not already connected and I'm on X at <a href="https://x.com/edwarddonner">@edwarddonner</a>. And my editor would be cross with me if I didn't mention one more time: it makes a HUGE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. <br/><br/>Massive thanks again for putting up with me for 8 weeks and getting all the way to the final cell! I'm excited to hear all about your career as an LLM Engineer. If you post on LinkedIn about completing the course and tag me, then I'll weigh in to amplify your achievement. <br/><b>You could not have picked a better time to be in this field.</b>
#             </span>
#         </td>
#     </tr>
# </table>
